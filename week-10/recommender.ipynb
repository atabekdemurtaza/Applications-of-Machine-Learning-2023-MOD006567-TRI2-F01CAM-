# %%
from IPython.display import Image

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
# Filenames with their paths.. change the path your file path!
# PATH="/Users/user1/Downloads/ml-25m/"
RATING_DATA_FILE="ratings.csv"
MOVIE_DATA_FILE="movies.csv"

# %%
# Read the ratings details from the csv file.
mov_df = pd.read_csv(RATING_DATA_FILE)

# %%
# Check a few entries in this file
mov_df.head()
# Out:
#    userId  movieId  rating     timestamp
# 0       1      296     5.0  1.147880e+09
# 1       1      306     3.5  1.147869e+09
# 2       1      307     5.0  1.147869e+09
# 3       1      665     5.0  1.147879e+09
# 4       1      899     3.5  1.147869e+09
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['movieId'].plot(kind='hist', bins=20, title='movieId')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['rating'].plot(kind='hist', bins=20, title='rating')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['timestamp'].plot(kind='hist', bins=20, title='timestamp')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3.plot(kind='scatter', x='movieId', y='rating', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='rating', y='timestamp', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['userId']
#   ys = series['rating']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_5.sort_values('userId', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('userId')
# _ = plt.ylabel('rating')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['userId']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'userId'}, axis=1)
#               .sort_values('userId', ascending=True))
#   xs = counted['userId']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_6.sort_values('userId', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('userId')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['movieId']
#   ys = series['rating']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_7.sort_values('movieId', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('movieId')
# _ = plt.ylabel('rating')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['movieId']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'movieId'}, axis=1)
#               .sort_values('movieId', ascending=True))
#   xs = counted['movieId']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_8.sort_values('movieId', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('movieId')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_9['movieId'].plot(kind='line', figsize=(8, 4), title='movieId')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['rating'].plot(kind='line', figsize=(8, 4), title='rating')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['timestamp'].plot(kind='line', figsize=(8, 4), title='timestamp')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# Load the dataset with movie details.
movie_titles = pd.read_csv(MOVIE_DATA_FILE)
movie_titles.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
# Merge the two dataframes to match movies with their ratings.
mov_df = pd.merge(mov_df, movie_titles, on='movieId')
mov_df.head()
# Out:
#    userId  movieId  rating     timestamp                title  \
# 0       1      296     5.0  1.147880e+09  Pulp Fiction (1994)
# 1       3      296     5.0  1.439474e+09  Pulp Fiction (1994)
# 2       4      296     4.0  1.573939e+09  Pulp Fiction (1994)
# 3       5      296     4.0  8.307862e+08  Pulp Fiction (1994)
# 4       7      296     4.0  8.354447e+08  Pulp Fiction (1994)
#
#                         genres
# 0  Comedy|Crime|Drama|Thriller
# 1  Comedy|Crime|Drama|Thriller
# 2  Comedy|Crime|Drama|Thriller
# 3  Comedy|Crime|Drama|Thriller
# 4  Comedy|Crime|Drama|Thriller

# %%
# Find the average and maximum values for rating.
mov_df.describe()
# Out:
#              userId       movieId        rating     timestamp
# count  1.144870e+06  1.144870e+06  1.144869e+06  1.144869e+06
# mean   3.895958e+03  2.096741e+04  3.539313e+00  1.207852e+09
# std    2.201827e+03  3.887050e+04  1.055929e+00  2.293856e+08
# min    1.000000e+00  1.000000e+00  5.000000e-01  7.896520e+08
# 25%    1.990000e+03  1.136000e+03  3.000000e+00  9.993784e+08
# 50%    3.903000e+03  2.827000e+03  4.000000e+00  1.181974e+09
# 75%    5.783000e+03  8.364000e+03  4.000000e+00  1.446401e+09
# max    7.721000e+03  2.091630e+05  5.000000e+00  1.574313e+09

# %%
# Remove all NAN values
mov_df.dropna(inplace=True)
mov_df.shape
# Out:
# (1144869, 6)

# %%
# Get average rating for each movie
ratings = pd.DataFrame(mov_df.groupby('title')['rating'].mean())
ratings.head()
# Out:
#                                     rating
# title
# "Great Performances" Cats (1998)  3.541667
# #realityhigh (2017)               3.000000
# $ (Dollars) (1971)                4.000000
# $5 a Day (2008)                   3.666667
# $9.99 (2008)                      2.750000

# %%
# Add to this number of users who rated this movie!
ratings['number_of_ratings'] = mov_df.groupby('title')['rating'].count()
ratings.head()
# Out:
#                                     rating  number_of_ratings
# title
# "Great Performances" Cats (1998)  3.541667                 12
# #realityhigh (2017)               3.000000                  1
# $ (Dollars) (1971)                4.000000                  1
# $5 a Day (2008)                   3.666667                  3
# $9.99 (2008)                      2.750000                  4

# %%
# Plotting the distribution of the movies
import matplotlib.pyplot as plt
# %matplotlib inline
ratings['rating'].hist(bins=50)
# Out:
# <Axes: >

# %%
# Visualise number of ratings similarily
ratings['number_of_ratings'].hist(bins=60)
# Out:
# <Axes: >

# %%
# Can we find the relationship between these two.
import seaborn as sns
sns.jointplot(x='rating', y='number_of_ratings', data=ratings)

# %%
# Sort the movies to find the top rated movies...
ratings.sort_values(by=['number_of_ratings'],ascending=False,inplace=True)

# %%
ratings.head()
# Out:
#                                     rating  number_of_ratings
# title
# Forrest Gump (1994)               4.057727               3837
# Shawshank Redemption, The (1994)  4.435547               3809
# Pulp Fiction (1994)               4.188818               3747
# Silence of the Lambs, The (1991)  4.132440               3545
# Matrix, The (1999)                4.156805               3380

# %%
# Lets work with top 500 movies!
top_rating = ratings[0:500]

# %%
# Check the values.
top_rating
# Out:
#                                                       rating  \
# title
# Forrest Gump (1994)                                 4.057727
# Shawshank Redemption, The (1994)                    4.435547
# Pulp Fiction (1994)                                 4.188818
# Silence of the Lambs, The (1991)                    4.132440
# Matrix, The (1999)                                  4.156805
# ...                                                      ...
# Three Kings (1999)                                  3.546243
# Hobbit: An Unexpected Journey, The (2012)           3.625241
# Nine Months (1995)                                  2.942085
# William Shakespeare's Romeo + Juliet (1996)         3.625483
# Like Water for Chocolate (Como agua para chocol...  3.910058
#
#                                                     number_of_ratings
# title
# Forrest Gump (1994)                                              3837
# Shawshank Redemption, The (1994)                                 3809
# Pulp Fiction (1994)                                              3747
# Silence of the Lambs, The (1991)                                 3545
# Matrix, The (1999)                                               3380
# ...                                                               ...
# Three Kings (1999)                                                519
# Hobbit: An Unexpected Journey, The (2012)                         519
# Nine Months (1995)                                                518
# William Shakespeare's Romeo + Juliet (1996)                       518
# Like Water for Chocolate (Como agua para chocol...                517
#
# [500 rows x 2 columns]

# %%
#Need to extract only these movies from the original data.
# So, check out what the earlier dataframe had.
mov_df.head()
# Out:
#    userId  movieId  rating     timestamp                title  \
# 0       1      296     5.0  1.147880e+09  Pulp Fiction (1994)
# 1       3      296     5.0  1.439474e+09  Pulp Fiction (1994)
# 2       4      296     4.0  1.573939e+09  Pulp Fiction (1994)
# 3       5      296     4.0  8.307862e+08  Pulp Fiction (1994)
# 4       7      296     4.0  8.354447e+08  Pulp Fiction (1994)
#
#                         genres
# 0  Comedy|Crime|Drama|Thriller
# 1  Comedy|Crime|Drama|Thriller
# 2  Comedy|Crime|Drama|Thriller
# 3  Comedy|Crime|Drama|Thriller
# 4  Comedy|Crime|Drama|Thriller

# %%
# In order to find the entries, reset the index to find the titles.
top_rating.reset_index(inplace=True)
top_rating.head()
# Out:
#                               title    rating  number_of_ratings
# 0               Forrest Gump (1994)  4.057727               3837
# 1  Shawshank Redemption, The (1994)  4.435547               3809
# 2               Pulp Fiction (1994)  4.188818               3747
# 3  Silence of the Lambs, The (1991)  4.132440               3545
# 4                Matrix, The (1999)  4.156805               3380

# %%
# Find details of only the toprated movies using the top rated titles.
topmovies_df = mov_df[mov_df["title"].isin(top_rating["title"])]

# %%
# Number of entries are alnmost halved. But it is still good enough for our study.
topmovies_df.shape
# Out:
# (508366, 6)

# %%
# The original data size for comparison.
mov_df.shape
# Out:
# (1144869, 6)

# %%
# Create the matrix discussed above with user Id as index and titles as
# columns with the value representing the real ratings.
movie_matrix = topmovies_df.pivot_table(index='userId', columns='title', values='rating')

# %%
# Check out the new matrix.
movie_matrix.head()
# Out:
# title   10 Things I Hate About You (1999)  12 Angry Men (1957)  \
# userId
# 1                                     NaN                  NaN
# 2                                     NaN                  NaN
# 3                                     NaN                  NaN
# 4                                     NaN                  NaN
# 5                                     NaN                  NaN
#
# title   2001: A Space Odyssey (1968)  28 Days Later (2002)  300 (2007)  \
# userId
# 1                                NaN                   NaN         NaN
# 2                                NaN                   NaN         NaN
# 3                                5.0                   3.0         4.0
# 4                                4.0                   NaN         NaN
# 5                                NaN                   NaN         NaN
#
# title   40-Year-Old Virgin, The (2005)  A.I. Artificial Intelligence (2001)  \
# userId
# 1                                  NaN                                  NaN
# 2                                  0.5                                  NaN
# 3                                  3.0                                  NaN
# 4                                  NaN                                  NaN
# 5                                  NaN                                  NaN
#
# title   Abyss, The (1989)  Ace Ventura: Pet Detective (1994)  \
# userId
# 1                     NaN                                NaN
# 2                     NaN                                NaN
# 3                     3.5                                NaN
# 4                     NaN                                NaN
# 5                     NaN                                4.0
#
# title   Ace Ventura: When Nature Calls (1995)  ...  \
# userId                                         ...
# 1                                         NaN  ...
# 2                                         NaN  ...
# 3                                         NaN  ...
# 4                                         NaN  ...
# 5                                         4.0  ...
#
# title   William Shakespeare's Romeo + Juliet (1996)  \
# userId
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
#
# title   Willy Wonka & the Chocolate Factory (1971)  Wizard of Oz, The (1939)  \
# userId
# 1                                              NaN                       NaN
# 2                                              NaN                       NaN
# 3                                              NaN                       NaN
# 4                                              NaN                       NaN
# 5                                              3.0                       NaN
#
# title   Wolf of Wall Street, The (2013)  \
# userId
# 1                                   NaN
# 2                                   NaN
# 3                                   4.5
# 4                                   NaN
# 5                                   NaN
#
# title   X-Files: Fight the Future, The (1998)  X-Men (2000)  \
# userId
# 1                                         NaN           NaN
# 2                                         NaN           5.0
# 3                                         4.0           4.0
# 4                                         NaN           1.5
# 5                                         NaN           NaN
#
# title   X2: X-Men United (2003)  You've Got Mail (1998)  \
# userId
# 1                           NaN                     NaN
# 2                           5.0                     NaN
# 3                           4.0                     NaN
# 4                           NaN                     NaN
# 5                           NaN                     NaN
#
# title   Young Frankenstein (1974)  Zombieland (2009)
# userId
# 1                             NaN                NaN
# 2                             NaN                NaN
# 3                             NaN                4.0
# 4                             4.0                NaN
# 5                             NaN                NaN
#
# [5 rows x 500 columns]

# %%
# Check out the movies with mazimum number of ratings.
top_rating.sort_values('number_of_ratings', ascending=False).head(10)
# Out:
#                                        title    rating  number_of_ratings
# 0                        Forrest Gump (1994)  4.057727               3837
# 1           Shawshank Redemption, The (1994)  4.435547               3809
# 2                        Pulp Fiction (1994)  4.188818               3747
# 3           Silence of the Lambs, The (1991)  4.132440               3545
# 4                         Matrix, The (1999)  4.156805               3380
# 5  Star Wars: Episode IV - A New Hope (1977)  4.102047               3224
# 6                       Jurassic Park (1993)  3.684350               3016
# 7                    Schindler's List (1993)  4.273924               2811
# 8                          Fight Club (1999)  4.227894               2782
# 9                          Braveheart (1995)  3.994220               2768

# %%
# Check out the movies with maximum rating!
top_rating.sort_values('rating', ascending=False).head(10)
# Out:
#                                       title    rating  number_of_ratings
# 1          Shawshank Redemption, The (1994)  4.435547               3809
# 18                    Godfather, The (1972)  4.351582               2402
# 68           Godfather: Part II, The (1974)  4.312821               1560
# 13               Usual Suspects, The (1995)  4.308000               2625
# 7                   Schindler's List (1993)  4.273924               2811
# 59   One Flew Over the Cuckoo's Nest (1975)  4.232424               1650
# 8                         Fight Club (1999)  4.227894               2782
# 204     City of God (Cidade de Deus) (2002)  4.221616                916
# 280                     12 Angry Men (1957)  4.212567                748
# 219                      Rear Window (1954)  4.211845                878

# %%
# Find the Forest Gump movie rating!
FG_user_rating = movie_matrix['Forrest Gump (1994)']

# %%
# Check out what values are in there.
FG_user_rating.head()
# Out:
# userId
# 1    NaN
# 2    4.5
# 3    4.0
# 4    NaN
# 5    4.0
# Name: Forrest Gump (1994), dtype: float64

# %%
# Find the movies with correlation to this movie.
similar_to_fg = movie_matrix.corrwith(FG_user_rating)

# %%
# Sort this to find the closest correlations!
similar_to_fg.sort_values(ascending=False).head()
# Out:
# title
# Forrest Gump (1994)           1.000000
# Saving Private Ryan (1998)    0.416946
# Rain Man (1988)               0.412425
# Green Mile, The (1999)        0.401196
# Time to Kill, A (1996)        0.400206
# dtype: float64

# %%
# Find the user rating for Schindler's List.
SL_user_rating = movie_matrix['Schindler\'s List (1993)']

# %%
SL_user_rating.head()

# %%
# Find the movies with correlation to this movie.
similar_to_sl=movie_matrix.corrwith(SL_user_rating)

# %%
#These are the movies similar to this movie
similar_to_sl.sort_values(ascending=False).head()

# %%
# Save the correlations as a dataframe
corr_SL = pd.DataFrame(similar_to_sl, columns=['correlation'])
corr_SL.dropna(inplace=True)
corr_SL.head()

# %%
corr_SL.shape

# %%
# Do the same for each movie.
corr_FG = pd.DataFrame(similar_to_fg, columns=['correlation'])
corr_FG.dropna(inplace=True)
corr_FG.head()

# %%
corr_FG.shape

# %%
# Need to add the ratings with the index movie title.
# Set the index of our ratings table to movie titles.
top_rating.set_index(['title'],inplace=True)
top_rating.head()

# %%
# Join this with the correlation table of first movie.
corr_SL = corr_SL.join(top_rating).sort_values(['correlation'],ascending=False)

# %%
corr_SL.head()

# %%
# Join this with the correlation table of second movie.
corr_FG=corr_FG.join(top_rating).sort_values(['correlation'],ascending=False)

# %%
corr_FG.head()
